# %%
# importing the libraries for data processing
import numpy as np 
import pandas as pd 

#matplotlib & seaborn for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# read and process the charts dataset
df_lola = pd.read_csv('data/artist_data_lola_amour.csv')
df_lola = df_lola.rename(columns={"track_popularity": "popularity"})
df_lola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           14 non-null     object
#  1   track_name         14 non-null     object
#  2   artist_id          14 non-null     object
#  3   artist_name        14 non-null     object
#  4   album_id           14 non-null     object
#  5   duration           14 non-null     int64
#  6   release_date       14 non-null     object
#  7   popularity         14 non-null     int64
#  8   danceability       14 non-null     float64
#  9   energy             14 non-null     float64
#  10  key                14 non-null     int64
#  11  loudness           14 non-null     float64
#  12  mode               14 non-null     int64
#  13  speechiness        14 non-null     float64
#  14  acousticness       14 non-null     float64
#  15  instrumentalness   14 non-null     float64
#  16  liveness           14 non-null     float64
#  17  valence            14 non-null     float64
#  18  tempo              14 non-null     float64
#  19  total_followers    14 non-null     int64
#  20  genres             14 non-null     object
#  21  artist_popularity  14 non-null     int64
# dtypes: float64(9), int64(6), object(7)
# memory usage: 2.5+ KB

# %%
# read playlists with top200 classification
df_clean = pd.read_csv('data/predicted_top_200_features.csv')
df_clean.head()
# Out:
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          29         0.475   0.157    0   -13.932     1       0.0307
# 1          46         0.603   0.196    6   -14.843     1       0.0443
# 2          24         0.649   0.902    7    -3.693     1       0.0601
# 3          24         0.555   0.637    9    -7.993     1       0.0356
# 4          68         0.544   0.781    8    -4.860     1       0.0352
#
#    acousticness  instrumentalness  liveness  valence    tempo  is_top200  \
# 0       0.78500          0.002120    0.1070   0.0806  119.836          0
# 1       0.94000          0.000001    0.0916   0.1600  119.529          0
# 2       0.08060          0.007800    0.1710   0.6410  122.988          0
# 3       0.00254          0.000785    0.0647   0.4890  124.999          0
# 4       0.00781          0.000084    0.1320   0.4220  124.869          0
#
#    predicted_top200  predicted_top200_prob
# 0                 0                    0.8
# 1                 0                    0.8
# 2                 0                    1.0
# 3                 0                    1.0
# 4                 0                    0.8

# %%
 df_clean[(df_clean['predicted_top200'] == df_clean['is_top200'])&(df_clean['is_top200']==1)].describe()
# Out:
#        popularity  danceability     energy        key   loudness       mode  \
# count   95.000000     95.000000  95.000000  95.000000  95.000000  95.000000
# mean    49.189474      0.547516   0.506038   5.821053  -8.586526   0.831579
# std     19.850663      0.134605   0.196719   3.135178   2.984414   0.376225
# min      0.000000      0.229000   0.025000   0.000000 -22.087000   0.000000
# 25%     45.000000      0.475000   0.372000   4.000000  -9.717500   1.000000
# 50%     57.000000      0.550000   0.507000   6.000000  -8.172000   1.000000
# 75%     62.000000      0.661000   0.635000   8.000000  -6.950500   1.000000
# max     72.000000      0.853000   0.969000  11.000000  -2.785000   1.000000
#
#        speechiness  acousticness  instrumentalness   liveness    valence  \
# count    95.000000     95.000000         95.000000  95.000000  95.000000
# mean      0.042965      0.373159          0.005494   0.159813   0.424137
# std       0.032053      0.285306          0.017387   0.102072   0.197896
# min       0.023200      0.000045          0.000000   0.033800   0.114000
# 25%       0.028700      0.123000          0.000000   0.096500   0.256500
# 50%       0.033300      0.360000          0.000005   0.117000   0.406000
# 75%       0.038600      0.588000          0.000458   0.203000   0.556500
# max       0.209000      0.904000          0.136000   0.688000   0.963000
#
#             tempo  is_top200  predicted_top200  predicted_top200_prob
# count   95.000000       95.0              95.0              95.000000
# mean   120.599253        1.0               1.0               0.972632
# std     28.810411        0.0               0.0               0.090439
# min     52.572000        1.0               1.0               0.600000
# 25%     94.286000        1.0               1.0               1.000000
# 50%    120.322000        1.0               1.0               1.000000
# 75%    144.295500        1.0               1.0               1.000000
# max    188.744000        1.0               1.0               1.000000

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    fig = plt.figure()
    ax= fig.add_subplot(111)
    
    sns.distplot(df_lola[col], ax=ax, label= 'lola amour')
    sns.distplot(df_clean[(df_clean['predicted_top200'] == df_clean['is_top200'])&(df_clean['is_top200']==1)][col], ax=ax, label= 'predicted_top200')
    
    plt.title("Lola Amour vs Prediction_Top200: %s " % (col))
    plt.ylabel('Frequency')
    plt.legend(frameon=False)
    plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
