# %%
import numpy as np
import pandas as pd

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import keyring
import time

# %% [markdown]
# ## Setup Spotipy credentials and query wrapper

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=keyring.get_password('spotify', 'cid'),
                                                      client_secret=keyring.get_password('spotify', 'secret') )
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ## Get sample artists data

# %%
df_tracks = pd.read_csv('../data/artist_discography.csv')

# %%
df_tracks.track_id.to_list()
# Out:
# ['4srf27evQWay0iKVUnxP0h',
#  '6yHovERMPPq0S8sKphNo1N',
#  '3MsCJJAGA6OdanJTvqvKBa',
#  '6Te15Q7bPL0S6jPg5KzZQT',
#  '56OFGWiYP7d0F0kA2fd7ZC',
#  '5B2muz6grNMnHUTCLyPhVB',
#  '0JfSoAS02Afe4UVr7LhCBB',
#  '1wK86WMTq9LcvDjVjMg1rh',
#  '3uQxelXb6c2IMuH5tsFNs2',
#  '0hBksOFr0Fs5mWLOliuD06',
#  '2pGH2MRfqXyFJtVPVBZ7Gx',
#  '1xRNFncLzJXA0niRz0BiXV',
#  '0HAciULA3lNbyp0kCBrJnC',
#  '72Xg79Z8uWLh48nKxuqwVF',
#  '7ctGuuUIbPWHDzvTl9ShUF',
#  '6aNHhxmx1HRz36hCD6aVBC',
#  '1AWixuiBqMJXRjSjhZe3wi',
#  '4YZTvhHtANW73ZkuDQYKFq',
#  '3k27ueIFNhgf7VtME2nynX',
#  '2yUrX68zHQyWsVGEp9MlCk',
#  '5BHPGYa53j3c9lnZRfYVqA',
#  '3g2Ef4btupLNRmwtxSgfyd',
#  '2r5uld98CoW00H9o6n8AKN',
#  '2xlYlIBkxeAgZn21Gc79b6',
#  '0LG4nrFaiB3p6CQcpAojNs',
#  '7bPFZSt9MLNDKphsWhTTTM',
#  '0tSLcXSAqjuEeEpGraNRXj',
#  '5d7hceIWVILdxMyk7PF1YW']

# %%
# View sp.artist output
sp.tracks(df_tracks.track_id.to_list())
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ft2hxnN8ZiOiusjSK3d1h'},
#     'href': 'https://api.spotify.com/v1/albums/5ft2hxnN8ZiOiusjSK3d1h',
#     'id': '5ft2hxnN8ZiOiusjSK3d1h',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273aeb989711ad59979e48d47d0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02aeb989711ad59979e48d47d0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851aeb989711ad59979e48d47d0',
#       'width': 64}],
#     'name': "Don't Look Back (Revisited)",
#     'release_date': '2020-11-12',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:5ft2hxnN8ZiOiusjSK3d1h'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 238080,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW012000334'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4srf27evQWay0iKVUnxP0h'},
#    'href': 'https://api.spotify.com/v1/tracks/4srf27evQWay0iKVUnxP0h',
#    'id': '4srf27evQWay0iKVUnxP0h',
#    'is_local': False,
#    'name': 'No Tomorrow (Revisited)',
#    'popularity': 24,
#    'preview_url': 'https://p.scdn.co/mp3-preview/746196769ad0bae7925cbd1d15d38578033aafd2?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4srf27evQWay0iKVUnxP0h'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ft2hxnN8ZiOiusjSK3d1h'},
#     'href': 'https://api.spotify.com/v1/albums/5ft2hxnN8ZiOiusjSK3d1h',
#     'id': '5ft2hxnN8ZiOiusjSK3d1h',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273aeb989711ad59979e48d47d0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02aeb989711ad59979e48d47d0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851aeb989711ad59979e48d47d0',
#       'width': 64}],
#     'name': "Don't Look Back (Revisited)",
#     'release_date': '2020-11-12',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:5ft2hxnN8ZiOiusjSK3d1h'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 303040,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW012000335'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6yHovERMPPq0S8sKphNo1N'},
#    'href': 'https://api.spotify.com/v1/tracks/6yHovERMPPq0S8sKphNo1N',
#    'id': '6yHovERMPPq0S8sKphNo1N',
#    'is_local': False,
#    'name': 'Maybe Maybe (Revisited)',
#    'popularity': 25,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f7a8156b19a070d45bcb04b71472e18030b6dcfd?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6yHovERMPPq0S8sKphNo1N'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ft2hxnN8ZiOiusjSK3d1h'},
#     'href': 'https://api.spotify.com/v1/albums/5ft2hxnN8ZiOiusjSK3d1h',
#     'id': '5ft2hxnN8ZiOiusjSK3d1h',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273aeb989711ad59979e48d47d0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02aeb989711ad59979e48d47d0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851aeb989711ad59979e48d47d0',
#       'width': 64}],
#     'name': "Don't Look Back (Revisited)",
#     'release_date': '2020-11-12',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:5ft2hxnN8ZiOiusjSK3d1h'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 200320,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW012000336'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3MsCJJAGA6OdanJTvqvKBa'},
#    'href': 'https://api.spotify.com/v1/tracks/3MsCJJAGA6OdanJTvqvKBa',
#    'id': '3MsCJJAGA6OdanJTvqvKBa',
#    'is_local': False,
#    'name': 'Fools (Revisited)',
#    'popularity': 24,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a3927a0fae1280786a9e9449b543f347f60fd857?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3MsCJJAGA6OdanJTvqvKBa'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ft2hxnN8ZiOiusjSK3d1h'},
#     'href': 'https://api.spotify.com/v1/albums/5ft2hxnN8ZiOiusjSK3d1h',
#     'id': '5ft2hxnN8ZiOiusjSK3d1h',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273aeb989711ad59979e48d47d0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02aeb989711ad59979e48d47d0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851aeb989711ad59979e48d47d0',
#       'width': 64}],
#     'name': "Don't Look Back (Revisited)",
#     'release_date': '2020-11-12',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:5ft2hxnN8ZiOiusjSK3d1h'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 159493,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW012000337'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Te15Q7bPL0S6jPg5KzZQT'},
#    'href': 'https://api.spotify.com/v1/tracks/6Te15Q7bPL0S6jPg5KzZQT',
#    'id': '6Te15Q7bPL0S6jPg5KzZQT',
#    'is_local': False,
#    'name': 'Please Don’t Leave',
#    'popularity': 32,
#    'preview_url': 'https://p.scdn.co/mp3-preview/715557cf64e9ab8f62828984cd997f8feda5f10d?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6Te15Q7bPL0S6jPg5KzZQT'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/47C3r7fnfLkZdsfaAGwPRL'},
#     'href': 'https://api.spotify.com/v1/albums/47C3r7fnfLkZdsfaAGwPRL',
#     'id': '47C3r7fnfLkZdsfaAGwPRL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273186c226aea47f081b6af4186',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02186c226aea47f081b6af4186',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851186c226aea47f081b6af4186',
#       'width': 64}],
#     'name': 'Pop Machine: Shake Yer Head',
#     'release_date': '2020-03-20',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:47C3r7fnfLkZdsfaAGwPRL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 222340,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMEZE1942618'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/56OFGWiYP7d0F0kA2fd7ZC'},
#    'href': 'https://api.spotify.com/v1/tracks/56OFGWiYP7d0F0kA2fd7ZC',
#    'id': '56OFGWiYP7d0F0kA2fd7ZC',
#    'is_local': False,
#    'name': 'Shake Yer Head',
#    'popularity': 29,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b4e62665c72c9c05b7d4ade0e942ce1131a5cda4?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:56OFGWiYP7d0F0kA2fd7ZC'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6y3WPaQdgMfX4Mw3hhAocu'},
#     'href': 'https://api.spotify.com/v1/albums/6y3WPaQdgMfX4Mw3hhAocu',
#     'id': '6y3WPaQdgMfX4Mw3hhAocu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27305b71fa6414e4bfa6cfe48a2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0205b71fa6414e4bfa6cfe48a2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485105b71fa6414e4bfa6cfe48a2',
#       'width': 64}],
#     'name': 'Pwede Ba (Korean Version)',
#     'release_date': '2020-01-17',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6y3WPaQdgMfX4Mw3hhAocu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 205000,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW012000002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5B2muz6grNMnHUTCLyPhVB'},
#    'href': 'https://api.spotify.com/v1/tracks/5B2muz6grNMnHUTCLyPhVB',
#    'id': '5B2muz6grNMnHUTCLyPhVB',
#    'is_local': False,
#    'name': 'Pwede Ba - Korean Version',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a0f2e8f6931269fad10869b1e199b36936143623?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5B2muz6grNMnHUTCLyPhVB'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7VQ1kVhVfNagytlousgm'},
#       'href': 'https://api.spotify.com/v1/artists/2G7VQ1kVhVfNagytlousgm',
#       'id': '2G7VQ1kVhVfNagytlousgm',
#       'name': 'Al James',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7VQ1kVhVfNagytlousgm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/388xKLbygotQvTqA0FMuwf'},
#     'href': 'https://api.spotify.com/v1/albums/388xKLbygotQvTqA0FMuwf',
#     'id': '388xKLbygotQvTqA0FMuwf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27309c359fe9dfc50f43cb31b82',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0209c359fe9dfc50f43cb31b82',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485109c359fe9dfc50f43cb31b82',
#       'width': 64}],
#     'name': 'Tuloy Na Tuloy Pa Rin Ang Pasko',
#     'release_date': '2019-12-09',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:388xKLbygotQvTqA0FMuwf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7VQ1kVhVfNagytlousgm'},
#      'href': 'https://api.spotify.com/v1/artists/2G7VQ1kVhVfNagytlousgm',
#      'id': '2G7VQ1kVhVfNagytlousgm',
#      'name': 'Al James',
#      'type': 'artist',
#      'uri': 'spotify:artist:2G7VQ1kVhVfNagytlousgm'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 215363,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW011900562'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0JfSoAS02Afe4UVr7LhCBB'},
#    'href': 'https://api.spotify.com/v1/tracks/0JfSoAS02Afe4UVr7LhCBB',
#    'id': '0JfSoAS02Afe4UVr7LhCBB',
#    'is_local': False,
#    'name': 'Tuloy Na Tuloy Pa Rin Ang Pasko',
#    'popularity': 33,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cee3021f09f4b0adf45e74d0e6186af047d45d38?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0JfSoAS02Afe4UVr7LhCBB'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6f2JnRkQ490vxmTKnfxe5L'},
#     'href': 'https://api.spotify.com/v1/albums/6f2JnRkQ490vxmTKnfxe5L',
#     'id': '6f2JnRkQ490vxmTKnfxe5L',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bdcebeb72c04e66f6b7ab936',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bdcebeb72c04e66f6b7ab936',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bdcebeb72c04e66f6b7ab936',
#       'width': 64}],
#     'name': 'Pa-Umaga (Cover Version)',
#     'release_date': '2019-10-20',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6f2JnRkQ490vxmTKnfxe5L'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 253352,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW011900525'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1wK86WMTq9LcvDjVjMg1rh'},
#    'href': 'https://api.spotify.com/v1/tracks/1wK86WMTq9LcvDjVjMg1rh',
#    'id': '1wK86WMTq9LcvDjVjMg1rh',
#    'is_local': False,
#    'name': 'Pa-Umaga - Cover Version',
#    'popularity': 25,
#    'preview_url': 'https://p.scdn.co/mp3-preview/254cdb85337f269204b57c7cb9aed4e147f99722?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1wK86WMTq9LcvDjVjMg1rh'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7VQ1kVhVfNagytlousgm'},
#       'href': 'https://api.spotify.com/v1/artists/2G7VQ1kVhVfNagytlousgm',
#       'id': '2G7VQ1kVhVfNagytlousgm',
#       'name': 'Al James',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7VQ1kVhVfNagytlousgm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3JeMA5cIY58m31aXTx1hUr'},
#     'href': 'https://api.spotify.com/v1/albums/3JeMA5cIY58m31aXTx1hUr',
#     'id': '3JeMA5cIY58m31aXTx1hUr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7cea9ad753fdf803c843bb8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7cea9ad753fdf803c843bb8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7cea9ad753fdf803c843bb8',
#       'width': 64}],
#     'name': 'Sundan Mo Ko',
#     'release_date': '2019-10-20',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3JeMA5cIY58m31aXTx1hUr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7VQ1kVhVfNagytlousgm'},
#      'href': 'https://api.spotify.com/v1/artists/2G7VQ1kVhVfNagytlousgm',
#      'id': '2G7VQ1kVhVfNagytlousgm',
#      'name': 'Al James',
#      'type': 'artist',
#      'uri': 'spotify:artist:2G7VQ1kVhVfNagytlousgm'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 265545,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW011900527'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3uQxelXb6c2IMuH5tsFNs2'},
#    'href': 'https://api.spotify.com/v1/tracks/3uQxelXb6c2IMuH5tsFNs2',
#    'id': '3uQxelXb6c2IMuH5tsFNs2',
#    'is_local': False,
#    'name': 'Sundan Mo Ko',
#    'popularity': 47,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d0b898155fb1e05d509090594931fab4f2cc80dd?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3uQxelXb6c2IMuH5tsFNs2'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2uX28zFrqZw4IbzsaEYaDm'},
#     'href': 'https://api.spotify.com/v1/albums/2uX28zFrqZw4IbzsaEYaDm',
#     'id': '2uX28zFrqZw4IbzsaEYaDm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273db3252eff10792ccbefcb8c7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02db3252eff10792ccbefcb8c7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851db3252eff10792ccbefcb8c7',
#       'width': 64}],
#     'name': 'Sanity',
#     'release_date': '2019-05-17',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2uX28zFrqZw4IbzsaEYaDm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 223802,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW011900246'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0hBksOFr0Fs5mWLOliuD06'},
#    'href': 'https://api.spotify.com/v1/tracks/0hBksOFr0Fs5mWLOliuD06',
#    'id': '0hBksOFr0Fs5mWLOliuD06',
#    'is_local': False,
#    'name': 'Sanity',
#    'popularity': 35,
#    'preview_url': 'https://p.scdn.co/mp3-preview/83cef2b29bf4db88f6774a9058e9ef37b6ad04c0?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0hBksOFr0Fs5mWLOliuD06'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/652wi7TL70B3QnNE2wwDSN'},
#     'href': 'https://api.spotify.com/v1/albums/652wi7TL70B3QnNE2wwDSN',
#     'id': '652wi7TL70B3QnNE2wwDSN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c48eb72be58e910d424437cf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c48eb72be58e910d424437cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c48eb72be58e910d424437cf',
#       'width': 64}],
#     'name': 'Pwede Ba',
#     'release_date': '2018-06-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:652wi7TL70B3QnNE2wwDSN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 342806,
#    'explicit': False,
#    'external_ids': {'isrc': 'USHM21825004'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2pGH2MRfqXyFJtVPVBZ7Gx'},
#    'href': 'https://api.spotify.com/v1/tracks/2pGH2MRfqXyFJtVPVBZ7Gx',
#    'id': '2pGH2MRfqXyFJtVPVBZ7Gx',
#    'is_local': False,
#    'name': 'Pwede Ba',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9f0241577fd85c15a8e4b6deab93f9f2ba98b28c?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2pGH2MRfqXyFJtVPVBZ7Gx'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#       'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#       'id': '29zSTMejPhY0m7kwNQ9SPI',
#       'name': 'Lola Amour',
#       'type': 'artist',
#       'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5eawUz4lU3YG3j79LhubBG'},
#     'href': 'https://api.spotify.com/v1/albums/5eawUz4lU3YG3j79LhubBG',
#     'id': '5eawUz4lU3YG3j79LhubBG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a0f4b651581705fa4d3ff04',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a0f4b651581705fa4d3ff04',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a0f4b651581705fa4d3ff04',
# ...
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Lokk4sIwvne6xEXHGClBQ'},
#     'href': 'https://api.spotify.com/v1/albums/2Lokk4sIwvne6xEXHGClBQ',
#     'id': '2Lokk4sIwvne6xEXHGClBQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f61f902002a0097d1aa2aa4d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f61f902002a0097d1aa2aa4d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f61f902002a0097d1aa2aa4d',
#       'width': 64}],
#     'name': 'Pop Machine the Album: A Collective of Artists Turning Heads This 2020',
#     'release_date': '2020-06-12',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2Lokk4sIwvne6xEXHGClBQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31MdQo1N4dx0kNM0ARbKqT'},
#      'href': 'https://api.spotify.com/v1/artists/31MdQo1N4dx0kNM0ARbKqT',
#      'id': '31MdQo1N4dx0kNM0ARbKqT',
#      'name': 'Pikoy',
#      'type': 'artist',
#      'uri': 'spotify:artist:31MdQo1N4dx0kNM0ARbKqT'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 228984,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMEZE1942344'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7bPFZSt9MLNDKphsWhTTTM'},
#    'href': 'https://api.spotify.com/v1/tracks/7bPFZSt9MLNDKphsWhTTTM',
#    'id': '7bPFZSt9MLNDKphsWhTTTM',
#    'is_local': False,
#    'name': 'Toyang',
#    'popularity': 6,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9aa2b55a59810a27f18bec9e023641ff9650b8d1?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:7bPFZSt9MLNDKphsWhTTTM'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Lokk4sIwvne6xEXHGClBQ'},
#     'href': 'https://api.spotify.com/v1/albums/2Lokk4sIwvne6xEXHGClBQ',
#     'id': '2Lokk4sIwvne6xEXHGClBQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f61f902002a0097d1aa2aa4d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f61f902002a0097d1aa2aa4d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f61f902002a0097d1aa2aa4d',
#       'width': 64}],
#     'name': 'Pop Machine the Album: A Collective of Artists Turning Heads This 2020',
#     'release_date': '2020-06-12',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2Lokk4sIwvne6xEXHGClBQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FH2eRnqnNwpcfwIFSTDWm'},
#      'href': 'https://api.spotify.com/v1/artists/2FH2eRnqnNwpcfwIFSTDWm',
#      'id': '2FH2eRnqnNwpcfwIFSTDWm',
#      'name': 'Riot Logic',
#      'type': 'artist',
#      'uri': 'spotify:artist:2FH2eRnqnNwpcfwIFSTDWm'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 215935,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMEZE1942600'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0tSLcXSAqjuEeEpGraNRXj'},
#    'href': 'https://api.spotify.com/v1/tracks/0tSLcXSAqjuEeEpGraNRXj',
#    'id': '0tSLcXSAqjuEeEpGraNRXj',
#    'is_local': False,
#    'name': 'Maselang Bahaghari',
#    'popularity': 5,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0ad1a3949536c64845c5eddc8ddb2a5c026fef83?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:0tSLcXSAqjuEeEpGraNRXj'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5D07XenBPdFIXWCj5vrpWC'},
#     'href': 'https://api.spotify.com/v1/albums/5D07XenBPdFIXWCj5vrpWC',
#     'id': '5D07XenBPdFIXWCj5vrpWC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273184d9ef855ef85d6b6f60943',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02184d9ef855ef85d6b6f60943',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851184d9ef855ef85d6b6f60943',
#       'width': 64}],
#     'name': 'Awit ng Bagong Taon',
#     'release_date': '2020-01-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5D07XenBPdFIXWCj5vrpWC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2nZ18B9RTjJH56v2NTnNAI'},
#      'href': 'https://api.spotify.com/v1/artists/2nZ18B9RTjJH56v2NTnNAI',
#      'id': '2nZ18B9RTjJH56v2NTnNAI',
#      'name': 'Leanne & Naara',
#      'type': 'artist',
#      'uri': 'spotify:artist:2nZ18B9RTjJH56v2NTnNAI'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2JI8ViuZDBybY6Xd9ujUrb'},
#      'href': 'https://api.spotify.com/v1/artists/2JI8ViuZDBybY6Xd9ujUrb',
#      'id': '2JI8ViuZDBybY6Xd9ujUrb',
#      'name': 'Reese Lansangan',
#      'type': 'artist',
#      'uri': 'spotify:artist:2JI8ViuZDBybY6Xd9ujUrb'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DouUeF604QbSdKYIL3xrq'},
#      'href': 'https://api.spotify.com/v1/artists/0DouUeF604QbSdKYIL3xrq',
#      'id': '0DouUeF604QbSdKYIL3xrq',
#      'name': 'Keiko Necesario',
#      'type': 'artist',
#      'uri': 'spotify:artist:0DouUeF604QbSdKYIL3xrq'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ebPSE9YI5aLeZ1Z2gkqjn'},
#      'href': 'https://api.spotify.com/v1/artists/5ebPSE9YI5aLeZ1Z2gkqjn',
#      'id': '5ebPSE9YI5aLeZ1Z2gkqjn',
#      'name': 'Clara Benin',
#      'type': 'artist',
#      'uri': 'spotify:artist:5ebPSE9YI5aLeZ1Z2gkqjn'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1X0JWLgaOjCDkuarzpTiWc'},
#      'href': 'https://api.spotify.com/v1/artists/1X0JWLgaOjCDkuarzpTiWc',
#      'id': '1X0JWLgaOjCDkuarzpTiWc',
#      'name': 'Pochoy Labog',
#      'type': 'artist',
#      'uri': 'spotify:artist:1X0JWLgaOjCDkuarzpTiWc'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/28B54RKpJrEmDoGSTjsfY6'},
#      'href': 'https://api.spotify.com/v1/artists/28B54RKpJrEmDoGSTjsfY6',
#      'id': '28B54RKpJrEmDoGSTjsfY6',
#      'name': 'Magnus Haven',
#      'type': 'artist',
#      'uri': 'spotify:artist:28B54RKpJrEmDoGSTjsfY6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/56p3ilIEBlYgDzOKA1HFQk'},
#      'href': 'https://api.spotify.com/v1/artists/56p3ilIEBlYgDzOKA1HFQk',
#      'id': '56p3ilIEBlYgDzOKA1HFQk',
#      'name': 'Hans Dimayuga',
#      'type': 'artist',
#      'uri': 'spotify:artist:56p3ilIEBlYgDzOKA1HFQk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5aquJZfDS2FWzG39lXbEN8'},
#      'href': 'https://api.spotify.com/v1/artists/5aquJZfDS2FWzG39lXbEN8',
#      'id': '5aquJZfDS2FWzG39lXbEN8',
#      'name': 'Davey Langit',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aquJZfDS2FWzG39lXbEN8'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4N7VMCvYd9Reh5bJLnRVzY'},
#      'href': 'https://api.spotify.com/v1/artists/4N7VMCvYd9Reh5bJLnRVzY',
#      'id': '4N7VMCvYd9Reh5bJLnRVzY',
#      'name': 'Quest',
#      'type': 'artist',
#      'uri': 'spotify:artist:4N7VMCvYd9Reh5bJLnRVzY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6urxZktbtGcTIIqxQZ1d8q'},
#      'href': 'https://api.spotify.com/v1/artists/6urxZktbtGcTIIqxQZ1d8q',
#      'id': '6urxZktbtGcTIIqxQZ1d8q',
#      'name': 'Jireh Lim',
#      'type': 'artist',
#      'uri': 'spotify:artist:6urxZktbtGcTIIqxQZ1d8q'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jKQrxK2zHqxyOAyIMrUQt'},
#      'href': 'https://api.spotify.com/v1/artists/0jKQrxK2zHqxyOAyIMrUQt',
#      'id': '0jKQrxK2zHqxyOAyIMrUQt',
#      'name': 'SUD',
#      'type': 'artist',
#      'uri': 'spotify:artist:0jKQrxK2zHqxyOAyIMrUQt'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6XMiJRtSvw0PYHOBSBEsMg'},
#      'href': 'https://api.spotify.com/v1/artists/6XMiJRtSvw0PYHOBSBEsMg',
#      'id': '6XMiJRtSvw0PYHOBSBEsMg',
#      'name': 'Barbie Almalbis',
#      'type': 'artist',
#      'uri': 'spotify:artist:6XMiJRtSvw0PYHOBSBEsMg'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EsbqfoNiHI0u1OaQUYDlI'},
#      'href': 'https://api.spotify.com/v1/artists/0EsbqfoNiHI0u1OaQUYDlI',
#      'id': '0EsbqfoNiHI0u1OaQUYDlI',
#      'name': 'EJ De Perio',
#      'type': 'artist',
#      'uri': 'spotify:artist:0EsbqfoNiHI0u1OaQUYDlI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 275666,
#    'explicit': False,
#    'external_ids': {'isrc': 'PHW012000008'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5d7hceIWVILdxMyk7PF1YW'},
#    'href': 'https://api.spotify.com/v1/tracks/5d7hceIWVILdxMyk7PF1YW',
#    'id': '5d7hceIWVILdxMyk7PF1YW',
#    'is_local': False,
#    'name': 'Awit ng Bagong Taon',
#    'popularity': 33,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f86adfa2473b67610fba570b945d0236e00e1399?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5d7hceIWVILdxMyk7PF1YW'}]}

# %%
artist_albums = sp.artist_albums(artist_id)
album_ids = []
for item in artist_albums['items']:
    if album_ids:
        album_ids.append(item['id'])
    else:
        album_ids = [item['id']]
album_ids
# Out:
# ['5ft2hxnN8ZiOiusjSK3d1h',
#  '47C3r7fnfLkZdsfaAGwPRL',
#  '6y3WPaQdgMfX4Mw3hhAocu',
#  '388xKLbygotQvTqA0FMuwf',
#  '6f2JnRkQ490vxmTKnfxe5L',
#  '3JeMA5cIY58m31aXTx1hUr',
#  '2uX28zFrqZw4IbzsaEYaDm',
#  '652wi7TL70B3QnNE2wwDSN',
#  '5eawUz4lU3YG3j79LhubBG',
#  '2Lokk4sIwvne6xEXHGClBQ',
#  '5D07XenBPdFIXWCj5vrpWC']

# %%
sp.album_tracks('5ft2hxnN8ZiOiusjSK3d1h')
# Out:
# {'href': 'https://api.spotify.com/v1/albums/5ft2hxnN8ZiOiusjSK3d1h/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 238080,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4srf27evQWay0iKVUnxP0h'},
#    'href': 'https://api.spotify.com/v1/tracks/4srf27evQWay0iKVUnxP0h',
#    'id': '4srf27evQWay0iKVUnxP0h',
#    'is_local': False,
#    'name': 'No Tomorrow (Revisited)',
#    'preview_url': 'https://p.scdn.co/mp3-preview/746196769ad0bae7925cbd1d15d38578033aafd2?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4srf27evQWay0iKVUnxP0h'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 303040,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6yHovERMPPq0S8sKphNo1N'},
#    'href': 'https://api.spotify.com/v1/tracks/6yHovERMPPq0S8sKphNo1N',
#    'id': '6yHovERMPPq0S8sKphNo1N',
#    'is_local': False,
#    'name': 'Maybe Maybe (Revisited)',
#    'preview_url': 'https://p.scdn.co/mp3-preview/f7a8156b19a070d45bcb04b71472e18030b6dcfd?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6yHovERMPPq0S8sKphNo1N'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 200320,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3MsCJJAGA6OdanJTvqvKBa'},
#    'href': 'https://api.spotify.com/v1/tracks/3MsCJJAGA6OdanJTvqvKBa',
#    'id': '3MsCJJAGA6OdanJTvqvKBa',
#    'is_local': False,
#    'name': 'Fools (Revisited)',
#    'preview_url': 'https://p.scdn.co/mp3-preview/a3927a0fae1280786a9e9449b543f347f60fd857?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3MsCJJAGA6OdanJTvqvKBa'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29zSTMejPhY0m7kwNQ9SPI'},
#      'href': 'https://api.spotify.com/v1/artists/29zSTMejPhY0m7kwNQ9SPI',
#      'id': '29zSTMejPhY0m7kwNQ9SPI',
#      'name': 'Lola Amour',
#      'type': 'artist',
#      'uri': 'spotify:artist:29zSTMejPhY0m7kwNQ9SPI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 159493,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Te15Q7bPL0S6jPg5KzZQT'},
#    'href': 'https://api.spotify.com/v1/tracks/6Te15Q7bPL0S6jPg5KzZQT',
#    'id': '6Te15Q7bPL0S6jPg5KzZQT',
#    'is_local': False,
#    'name': 'Please Don’t Leave',
#    'preview_url': 'https://p.scdn.co/mp3-preview/715557cf64e9ab8f62828984cd997f8feda5f10d?cid=d89651f9f37342179784497e4e4ed236',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6Te15Q7bPL0S6jPg5KzZQT'}],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 4}

# %% [markdown]
# ## Get artist's album discography

# %%
def get_discography(a_id):
    artist_albums = sp.artist_albums(a_id)
    artist_name = sp.artist(a_id)['name']
    
    # Add album ids to list
    album_ids = []
    for item in artist_albums['items']:
        album = {'id': item['id'], 'name':item['name']}
        if album_ids:
            album_ids.append(album)
        else:
            album_ids = [album]
    
    # Get tracks from each album
    album_data = []
    for album in album_ids:
        track_data = sp.album_tracks(album['id'])['items']
        for track in track_data:
            row = [artist_id,
                   artist_name,
                   album['id'],
                   album['name'],
                   track['id'],
                   track['name'],
                   track['duration_ms'],
                   track['track_number']]
            if album_data:
                album_data.append(row)
            else:
                album_data = [row]
                
    return album_data

# %%
artist_discography = pd.DataFrame(get_discography(artist_id), columns=['artist_id','artist_name','album_id','album_name',
                                                  'track_id','track_name','track_length','track_number'])

# %%
artist_discography.to_csv('../data/artist_discography.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Resources
# - Spotify API reference manual https://developer.spotify.com/documentation/web-api/reference/search/search/
