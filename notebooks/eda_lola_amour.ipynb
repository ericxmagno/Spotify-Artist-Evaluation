# %% [markdown]
# ## Importing Libraries

# %%
# importing the libraries for data processing
import numpy as np 
import pandas as pd 

#matplotlib & seaborn for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading the data set

# %%
# read and process the charts dataset
df_lola = pd.read_csv('data/artist_data_lola_amour.csv')
df_lola.head()
# Out:
#                  track_id          track_name               artist_id  \
# 0  2pGH2MRfqXyFJtVPVBZ7Gx            Pwede Ba  29zSTMejPhY0m7kwNQ9SPI
# 1  0HAciULA3lNbyp0kCBrJnC         Maybe Maybe  29zSTMejPhY0m7kwNQ9SPI
# 2  72Xg79Z8uWLh48nKxuqwVF         No Tomorrow  29zSTMejPhY0m7kwNQ9SPI
# 3  6Te15Q7bPL0S6jPg5KzZQT  Please Don’t Leave  29zSTMejPhY0m7kwNQ9SPI
# 4  0hBksOFr0Fs5mWLOliuD06              Sanity  29zSTMejPhY0m7kwNQ9SPI
#
#   artist_name                album_id  duration release_date  \
# 0  Lola Amour  652wi7TL70B3QnNE2wwDSN    342806   2018-06-15
# 1  Lola Amour  5eawUz4lU3YG3j79LhubBG    313500   2017-05-16
# 2  Lola Amour  5eawUz4lU3YG3j79LhubBG    188000   2017-05-16
# 3  Lola Amour  5ft2hxnN8ZiOiusjSK3d1h    159493   2020-11-12
# 4  Lola Amour  2uX28zFrqZw4IbzsaEYaDm    223802   2019-05-17
#
#    track_popularity  danceability  energy  ...  mode  speechiness  \
# 0                53         0.665   0.325  ...     1       0.0544
# 1                42         0.648   0.316  ...     1       0.0277
# 2                34         0.624   0.379  ...     1       0.0332
# 3                32         0.462   0.169  ...     1       0.0309
# 4                35         0.724   0.571  ...     0       0.0396
#
#    acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.607          0.000429    0.1050    0.253   79.496
# 1         0.434          0.000013    0.1230    0.308   99.006
# 2         0.656          0.000000    0.3200    0.487   91.972
# 3         0.967          0.000000    0.1180    0.343  135.103
# 4         0.159          0.000000    0.0613    0.775   99.957
#
#    total_followers                         genres  artist_popularity
# 0            75309  ['pinoy indie', 'pinoy rock']                 48
# 1            75309  ['pinoy indie', 'pinoy rock']                 48
# 2            75309  ['pinoy indie', 'pinoy rock']                 48
# 3            75309  ['pinoy indie', 'pinoy rock']                 48
# 4            75309  ['pinoy indie', 'pinoy rock']                 48
#
# [5 rows x 22 columns]

# %%
df_lola = df_lola.rename(columns={"track_popularity": "popularity"})

# %%
df_lola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           14 non-null     object
#  1   track_name         14 non-null     object
#  2   artist_id          14 non-null     object
#  3   artist_name        14 non-null     object
#  4   album_id           14 non-null     object
#  5   duration           14 non-null     int64
#  6   release_date       14 non-null     object
#  7   popularity         14 non-null     int64
#  8   danceability       14 non-null     float64
#  9   energy             14 non-null     float64
#  10  key                14 non-null     int64
#  11  loudness           14 non-null     float64
#  12  mode               14 non-null     int64
#  13  speechiness        14 non-null     float64
#  14  acousticness       14 non-null     float64
#  15  instrumentalness   14 non-null     float64
#  16  liveness           14 non-null     float64
#  17  valence            14 non-null     float64
#  18  tempo              14 non-null     float64
#  19  total_followers    14 non-null     int64
#  20  genres             14 non-null     object
#  21  artist_popularity  14 non-null     int64
# dtypes: float64(9), int64(6), object(7)
# memory usage: 2.5+ KB

# %% [markdown]
# ## EDA

# %%
viz_data = df_lola.drop(columns=['track_id', 'track_name', 'artist_name', 'artist_id', 'album_id', 'duration',\
                                 'release_date', 'genres', 'total_followers', 'artist_popularity'])
viz_data.shape
# Out:
# (14, 12)

# %%
plt.subplots(figsize=(16, 6))
sns.heatmap(viz_data.corr(), annot=True)
plt.show()

# %%
df_lola.describe()
# Out:
#             duration  popularity  danceability     energy        key  \
# count      14.000000   14.000000     14.000000  14.000000  14.000000
# mean   228719.500000   29.571429      0.632357   0.426357   5.642857
# std     63838.340222   10.945419      0.088550   0.197412   4.125104
# min     92500.000000    5.000000      0.446000   0.125000   0.000000
# 25%    201490.000000   24.250000      0.625250   0.318250   2.000000
# 50%    223071.000000   28.000000      0.646000   0.410000   8.500000
# 75%    249534.000000   34.750000      0.680000   0.557250   9.000000
# max    342806.000000   53.000000      0.748000   0.740000  10.000000
#
#         loudness       mode  speechiness  acousticness  instrumentalness  \
# count  14.000000  14.000000    14.000000     14.000000      1.400000e+01
# mean   -9.003857   0.857143     0.034864      0.472071      1.138591e-03
# std     3.282953   0.363137     0.007327      0.308580      2.993577e-03
# min   -16.989000   0.000000     0.026500      0.056400      0.000000e+00
# 25%   -11.255750   1.000000     0.030525      0.157500      5.025000e-07
# 50%    -8.495500   1.000000     0.032450      0.525500      5.630000e-06
# 75%    -6.502000   1.000000     0.038300      0.643750      3.449500e-04
# max    -5.314000   1.000000     0.054400      0.967000      1.120000e-02
#
#         liveness    valence       tempo  total_followers  artist_popularity
# count  14.000000  14.000000   14.000000             14.0               14.0
# mean    0.132150   0.461000  106.850000          75309.0               48.0
# std     0.073595   0.220368   18.945172              0.0                0.0
# min     0.061300   0.183000   79.496000          75309.0               48.0
# 25%     0.091700   0.298250   93.730500          75309.0               48.0
# 50%     0.107500   0.362500  102.025500          75309.0               48.0
# 75%     0.141000   0.670250  127.302250          75309.0               48.0
# max     0.320000   0.789000  135.103000          75309.0               48.0

# %% [markdown]
# ## Loading the playlists (pinoy indie, pinoy rock)

# %%
#set keyword
KEYWORD1='pinoy indie'

# %%
# read and process the playlist data for keyword
tracks1_df = pd.read_csv('data/'+KEYWORD1+'_playlist_tracks_data.csv')\
                .merge(pd.read_csv('data/'+KEYWORD1+'_playlist_tracks.csv')[['track_id','playlist_id','playlist_name']],\
                      on='track_id',how='left')
#make duration ms to minutes
tracks1_df['duration_mins']=tracks1_df['duration']/60000
#tag genre with keyword
tracks1_df['genre']=KEYWORD1
tracks1_df.head()
# Out:
#                  track_id          track_name               artist_id  \
# 0  2g6Wkzji3cHY6NLghAo4eY       Matulog ka na  6QS0EHo0EInPROmIqLIBGd
# 1  78heomO2buqJes1Zf5IOdf           Kwentuhan  3Hvxz2oZPYuo61ChHKcqQI
# 2  2AyWbcZ3SZcHphIUktXaBK  Take Me for Awhile  62BlzCSrFVs8LktOArIoDW
# 3  3kb7ReTd6zyMENiL5WU30j        Stranger Now  4sKYcezEK11EMLONEhInb0
# 4  3kb7ReTd6zyMENiL5WU30j        Stranger Now  4sKYcezEK11EMLONEhInb0
#
#        artist_name                album_id  duration release_date  popularity  \
# 0          Clayson  5yqsmaQV33Ak9EDzKPfFzo    279106   2021-01-22          29
# 1        Autotelic  2AIsdW4H6Yy5XiMHh4ztS0    269333   2021-01-22          37
# 2   darwin navarro  3WK4OYJfkt6jzGhla4JxJm    242620   2021-01-22          25
# 3  Marion Talavera  5SA0GFx1h3s0goizmFD0xj    201663   2020-04-10          46
# 4  Marion Talavera  5SA0GFx1h3s0goizmFD0xj    201663   2020-04-10          46
#
#    danceability  energy  ...  instrumentalness  liveness  valence    tempo  \
# 0         0.475   0.157  ...          0.002120    0.1070   0.0806  119.836
# 1         0.406   0.742  ...          0.000410    0.0943   0.5640  179.959
# 2         0.523   0.759  ...          0.000769    0.1090   0.6030   90.026
# 3         0.603   0.196  ...          0.000001    0.0916   0.1600  119.529
# 4         0.603   0.196  ...          0.000001    0.0916   0.1600  119.529
#
#             playlist_id_x         playlist_name_x           playlist_id_y  \
# 0  2g6Wkzji3cHY6NLghAo4eY  2g6Wkzji3cHY6NLghAo4eY  37i9dQZF1DX6oLdwrroY56
# 1  78heomO2buqJes1Zf5IOdf  78heomO2buqJes1Zf5IOdf  37i9dQZF1DX6oLdwrroY56
# 2  2AyWbcZ3SZcHphIUktXaBK  2AyWbcZ3SZcHphIUktXaBK  37i9dQZF1DX6oLdwrroY56
# 3  3kb7ReTd6zyMENiL5WU30j  3kb7ReTd6zyMENiL5WU30j  37i9dQZF1DX6oLdwrroY56
# 4  3kb7ReTd6zyMENiL5WU30j  3kb7ReTd6zyMENiL5WU30j  3eWBjL2f97qCYVOZi1JwhS
#
#             playlist_name_y  duration_mins        genre
# 0           Pinoy Indie Mix       4.651767  pinoy indie
# 1           Pinoy Indie Mix       4.488883  pinoy indie
# 2           Pinoy Indie Mix       4.043667  pinoy indie
# 3           Pinoy Indie Mix       3.361050  pinoy indie
# 4  Maru's Pinoy Indie Picks       3.361050  pinoy indie
#
# [5 rows x 25 columns]

# %%
tracks1_df.shape
# Out:
# (2813, 25)

# %%
tracks1_df.to_csv('data/df_merged_playlist1.csv', index=False, encoding='utf-8')

# %%
# How many unique tracks are in playlist set 1?
len(tracks1_df['track_id'].unique())
# Out:
# 1582

# %%
#set keyword
KEYWORD2='pinoy rock'

# %%
# read and process the playlist data for keyword
tracks2_df = pd.read_csv('data/'+KEYWORD2+'_playlist_tracks_data.csv')\
                .merge(pd.read_csv('data/'+KEYWORD2+'_playlist_tracks.csv')[['track_id','playlist_id','playlist_name']],\
                      on='track_id',how='left')
#make duration ms to minutes
tracks2_df['duration_mins']=tracks2_df['duration']/60000
#tag genre with keyword
tracks2_df['genre']=KEYWORD2
tracks2_df.head()
# Out:
#                  track_id           track_name               artist_id  \
# 0  21LMl54FIe7J5oOoZzgeiQ  Ang Huling El Bimbo  7374lH6kwx9uQATYQ9H3Cp
# 1  21LMl54FIe7J5oOoZzgeiQ  Ang Huling El Bimbo  7374lH6kwx9uQATYQ9H3Cp
# 2  21LMl54FIe7J5oOoZzgeiQ  Ang Huling El Bimbo  7374lH6kwx9uQATYQ9H3Cp
# 3  21LMl54FIe7J5oOoZzgeiQ  Ang Huling El Bimbo  7374lH6kwx9uQATYQ9H3Cp
# 4  21LMl54FIe7J5oOoZzgeiQ  Ang Huling El Bimbo  7374lH6kwx9uQATYQ9H3Cp
#
#    artist_name                album_id  duration release_date  popularity  \
# 0  Eraserheads  2DIpgoeZAbwk3wF1qSDj8v    450333   2004-01-23          56
# 1  Eraserheads  2DIpgoeZAbwk3wF1qSDj8v    450333   2004-01-23          56
# 2  Eraserheads  2DIpgoeZAbwk3wF1qSDj8v    450333   2004-01-23          56
# 3  Eraserheads  2DIpgoeZAbwk3wF1qSDj8v    450333   2004-01-23          56
# 4  Eraserheads  2DIpgoeZAbwk3wF1qSDj8v    450333   2004-01-23          56
#
#    danceability  energy  ...  instrumentalness  liveness  valence   tempo  \
# 0         0.521   0.626  ...               0.0     0.227    0.479  90.337
# 1         0.521   0.626  ...               0.0     0.227    0.479  90.337
# 2         0.521   0.626  ...               0.0     0.227    0.479  90.337
# 3         0.521   0.626  ...               0.0     0.227    0.479  90.337
# 4         0.521   0.626  ...               0.0     0.227    0.479  90.337
#
#             playlist_id_x         playlist_name_x           playlist_id_y  \
# 0  21LMl54FIe7J5oOoZzgeiQ  21LMl54FIe7J5oOoZzgeiQ  5vwEkzy091ZXNLD3eyavbt
# 1  21LMl54FIe7J5oOoZzgeiQ  21LMl54FIe7J5oOoZzgeiQ  4ca4u53Xr749bgcj0E9fj9
# 2  21LMl54FIe7J5oOoZzgeiQ  21LMl54FIe7J5oOoZzgeiQ  3ZZoZhamZh4wyTbFO5Wcum
# 3  21LMl54FIe7J5oOoZzgeiQ  21LMl54FIe7J5oOoZzgeiQ  1POkDLkngVCP4yfwaIQ34b
# 4  21LMl54FIe7J5oOoZzgeiQ  21LMl54FIe7J5oOoZzgeiQ  2Mm6vIQwi11WgoST4HNFoX
#
#                            playlist_name_y  duration_mins       genre
# 0  Tunog Kalye / Pinoy Rock OPM Bands 90's        7.50555  pinoy rock
# 1      Pinoy Rock/Rap/Hip-Hop/Alternative         7.50555  pinoy rock
# 2                         90's  Pinoy Rock        7.50555  pinoy rock
# 3                         Pinoy Rock Bands        7.50555  pinoy rock
# 4                    90's pinoy rock songs        7.50555  pinoy rock
#
# [5 rows x 25 columns]

# %%
tracks2_df.to_csv('data/df_merged_playlist2.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Check distribution

# %%
a = 'popularity'
KEYWORD1+'_'+a+'.png'
# Out:
# 'pinoy indie_popularity.png'

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    fig = plt.figure()
    ax= fig.add_subplot(111)
    
    sns.distplot(df_lola[col], ax=ax, label= 'lola amour')
    sns.distplot(tracks1_df[col], ax=ax, label= KEYWORD1)
    plt.title("Lola Amour vs %s: %s " % (KEYWORD1,col))
    plt.ylabel('Frequency')
    plt.legend(frameon=False)
    plt.show()
    plt.savefig(fname = KEYWORD1+'_'+col+'.png')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for col in ['popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo']:
    fig = plt.figure()
    ax= fig.add_subplot(111)
    
    sns.distplot(df_lola[col], ax=ax, label= 'lola amour')
    sns.distplot(tracks2_df[col], ax=ax, label= KEYWORD2)
    plt.title("Lola Amour vs %s: %s " % (KEYWORD2,col))
    plt.ylabel('Frequency')
    plt.legend(frameon=False)
    plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
